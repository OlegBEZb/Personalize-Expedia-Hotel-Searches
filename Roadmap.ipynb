# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

# %% [markdown]
# the second public score is for sure a wild overfit

# %%
public_scores = [0.32661, 0.36825, 0.36995, 0.36163, 0.33767, 0.31550, 0.33190]
local_test_scores = [0.32595, 0.78699, 0.37916, 0.36886, 0.37758, 0.35682, 0.38264]
local_val_scores = [np.nan, np.nan, np.nan, np.nan, 0.36971, 0.35554, 0.38184]
local_train_scores = [np.nan, np.nan, np.nan, np.nan, 0.12225, 0.07871, 0.18755]

# %%
plt.figure(figsize=(10, 5))
plt.plot(public_scores, marker='+', label='public')
plt.plot(local_test_scores, marker='+', label='local test')
plt.plot(local_val_scores, marker='+', label='local val')
plt.plot(local_train_scores, marker='+', label='local train')
plt.xlabel('submission', fontsize=14)
plt.xticks(np.arange(len(public_scores)), np.arange(1, len(public_scores)+1))
plt.ylabel('NDCG', fontsize=14)
plt.title('NDCG scores')
plt.legend(fontsize=12);
